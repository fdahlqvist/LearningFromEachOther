# %%
from aalpy.utils import generate_random_deterministic_automata
from aalpy.SULs import AutomatonSUL
from aalpy.oracles import RandomWMethodEqOracle, RandomWalkEqOracle
from aalpy.learning_algs import run_KV, run_Lstar

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import SimpleRNN
# Out:
# 2025-02-04 18:22:54.866862: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Exact learning of the Reber DFA used in
# Cleeremans, Axel, David Servan-Schreiber, and James L. McClelland. "Finite state automata and simple recurrent networks." Neural computation 1.3 (1989): 372-381.

# %%
# The Reber dfa from Reber, A.S. 1967. Implicit learning of artificial grammars. I. Verbal Leartiing Verbal Behau. 5, 855-863.
# A sink state is added to make it a proper dfa
def get_reber_dfa():
    from aalpy.automata import Dfa
    
    reber_dfa = {
        'q0': (False, {'t': 'q1', 'p': 'q2', 's': 'sink', 'x': 'sink', 'v': 'sink'}),
        'q1': (False, {'s': 'q1', 'x': 'q3', 't': 'sink', 'p': 'sink', 'v': 'sink'}),
        'q2': (False, {'t': 'q2', 'v': 'q4', 's': 'sink', 'x': 'sink', 'p': 'sink'}),
        'q3': (False, {'s': 'q5', 'x': 'q2', 't': 'sink', 'p': 'sink', 'v': 'sink'}),
        'q4': (False, {'p': 'q3', 'v': 'q5', 's': 'sink', 'x': 'sink', 't': 'sink'}),
        'q5': (True, {'t': 'sink', 'p': 'sink', 's': 'sink', 'x': 'sink', 'v': 'sink'}),
        'sink': (False, {'t': 'sink', 'p': 'sink', 's': 'sink', 'x': 'sink', 'v': 'sink'})
    }

    return Dfa.from_state_setup(reber_dfa)

# %%
# Using RandomWalkEqOracle
reber_dfa= get_reber_dfa()
alphabet = reber_dfa.get_input_alphabet()

sul = AutomatonSUL(reber_dfa)
eq_oracle = RandomWalkEqOracle(alphabet, sul, 1500)

learned_dfa = run_Lstar(alphabet, sul, eq_oracle, automaton_type='dfa',
                        cache_and_non_det_check=True, cex_processing=None, print_level=3)

assert learned_dfa == reber_dfa

print(reber_dfa)

print(learned_dfa)
# Out:
# Hypothesis 1: 1 states.
# ------------------------
# Prefixes / E set |()
# ------------------------
# ()               |False
# ========================
# ------------------------
# ('t',)           |False
# ------------------------
# ('p',)           |False
# ------------------------
# ('s',)           |False
# ------------------------
# ('x',)           |False
# ------------------------
# ('v',)           |False
# ------------------------
# Counterexample ('p', 'v', 'v')
# Hypothesis 2: 4 states.
# ----------------------------------------------------
# Prefixes / E set     |()    |('v',) |('v', 'v')
# ----------------------------------------------------
# ()                   |False |False  |(False, False)
# ----------------------------------------------------
# ('p',)               |False |False  |(False, True)
# ----------------------------------------------------
# ('p', 'v')           |False |True   |(True, False)
# ----------------------------------------------------
# ('p', 'v', 'v')      |True  |False  |(False, False)
# ====================================================
# ----------------------------------------------------
# ('t',)               |False |False  |(False, False)
# ----------------------------------------------------
# ('s',)               |False |False  |(False, False)
# ----------------------------------------------------
# ('x',)               |False |False  |(False, False)
# ----------------------------------------------------
# ('v',)               |False |False  |(False, False)
# ----------------------------------------------------
# ('p', 't')           |False |False  |(False, True)
# ----------------------------------------------------
# ('p', 'p')           |False |False  |(False, False)
# ----------------------------------------------------
# ('p', 's')           |False |False  |(False, False)
# ----------------------------------------------------
# ('p', 'x')           |False |False  |(False, False)
# ----------------------------------------------------
# ('p', 'v', 't')      |False |False  |(False, False)
# ----------------------------------------------------
# ('p', 'v', 'p')      |False |False  |(False, False)
# ----------------------------------------------------
# ('p', 'v', 's')      |False |False  |(False, False)
# ----------------------------------------------------
# ('p', 'v', 'x')      |False |False  |(False, False)
# ----------------------------------------------------
# ('p', 'v', 'v', 't') |False |False  |(False, False)
# ----------------------------------------------------
# ('p', 'v', 'v', 'p') |False |False  |(False, False)
# ----------------------------------------------------
# ('p', 'v', 'v', 's') |False |False  |(False, False)
# ----------------------------------------------------
# ('p', 'v', 'v', 'x') |False |False  |(False, False)
# ----------------------------------------------------
# ('p', 'v', 'v', 'v') |False |False  |(False, False)
# ----------------------------------------------------
# Counterexample ('s', 'p', 'v', 'v')
# Hypothesis 3: 5 states.
# --------------------------------------------------------------------------------
# Prefixes / E set          |()    |('v',) |('v', 'v')     |('p', 'v', 'v')
# --------------------------------------------------------------------------------
# ()                        |False |False  |(False, False) |(False, False, True)
# --------------------------------------------------------------------------------
# ('p',)                    |False |False  |(False, True)  |(False, False, False)
# --------------------------------------------------------------------------------
# ('s',)                    |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'v')                |False |True   |(True, False)  |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p')                |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'v', 'v')           |True  |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'v')           |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'v', 'v')      |False |False  |(False, False) |(False, False, False)
# ================================================================================
# --------------------------------------------------------------------------------
# ('t',)                    |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('x',)                    |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('v',)                    |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 't')                |False |False  |(False, True)  |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'p')                |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 's')                |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'x')                |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 't')                |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 's')                |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'x')                |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'v')                |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'v', 't')           |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'v', 'p')           |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'v', 's')           |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'v', 'x')           |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 't')           |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'p')           |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 's')           |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'x')           |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'v', 'v', 't')      |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'v', 'v', 'p')      |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'v', 'v', 's')      |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'v', 'v', 'x')      |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('p', 'v', 'v', 'v')      |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'v', 't')      |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'v', 'p')      |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'v', 's')      |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'v', 'x')      |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'v', 'v', 't') |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'v', 'v', 'p') |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'v', 'v', 's') |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'v', 'v', 'x') |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# ('s', 'p', 'v', 'v', 'v') |False |False  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------
# Counterexample ('t', 'x', 's')
# Hypothesis 4: 7 states.
# --------------------------------------------------------------------------------------------------------
# Prefixes / E set          |()    |('v',) |('v', 'v')     |('p', 'v', 'v')       |('s',) |('x', 's')
# --------------------------------------------------------------------------------------------------------
# ()                        |False |False  |(False, False) |(False, False, True)  |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p',)                    |False |False  |(False, True)  |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s',)                    |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t',)                    |False |False  |(False, False) |(False, False, False) |False  |(False, True)
# --------------------------------------------------------------------------------------------------------
# ('p', 'v')                |False |True   |(True, False)  |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p')                |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 'x')                |False |False  |(False, False) |(False, False, False) |True   |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 'v', 'v')           |True  |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'v')           |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 'x', 's')           |True  |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'v', 'v')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# ========================================================================================================
# --------------------------------------------------------------------------------------------------------
# ('x',)                    |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('v',)                    |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 't')                |False |False  |(False, True)  |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 'p')                |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 's')                |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 'x')                |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 't')                |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 's')                |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'x')                |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'v')                |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 't')                |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 'p')                |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 's')                |False |False  |(False, False) |(False, False, False) |False  |(False, True)
# --------------------------------------------------------------------------------------------------------
# ('t', 'v')                |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 'v', 't')           |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 'v', 'p')           |False |False  |(False, False) |(False, False, False) |True   |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 'v', 's')           |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 'v', 'x')           |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 't')           |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'p')           |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 's')           |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'x')           |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 'x', 't')           |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 'x', 'p')           |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 'x', 'x')           |False |False  |(False, True)  |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 'x', 'v')           |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 'v', 'v', 't')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 'v', 'v', 'p')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 'v', 'v', 's')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 'v', 'v', 'x')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('p', 'v', 'v', 'v')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'v', 't')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'v', 'p')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'v', 's')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'v', 'x')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 't')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 'p')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 's')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 'x')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 'v')      |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'v', 'v', 't') |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'v', 'v', 'p') |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'v', 'v', 's') |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'v', 'v', 'x') |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# ('s', 'p', 'v', 'v', 'v') |False |False  |(False, False) |(False, False, False) |False  |(False, False)
# --------------------------------------------------------------------------------------------------------
# -----------------------------------
# Learning Finished.
# Learning Rounds:  4
# Number of states: 7
# Time (in seconds)
#   Total                : 0.03
#   Learning algorithm   : 0.02
#   Conformance checking : 0.01
# Learning Algorithm
#  # Membership Queries  : 247
#  # MQ Saved by Caching : 92
#  # Steps               : 1190
# Equivalence Query
#  # Membership Queries  : 220
#  # Steps               : 2365
# -----------------------------------
# digraph learnedModel {
# q0 [label="q0"];
# q1 [label="q1"];
# q2 [label="q2"];
# q3 [label="q3"];
# q4 [label="q4"];
# q5 [label="q5", shape=doublecircle];
# sink [label="sink"];
# q0 -> q1 [label="t"];
# q0 -> q2 [label="p"];
# q0 -> sink [label="s"];
# q0 -> sink [label="x"];
# q0 -> sink [label="v"];
# q1 -> q1 [label="s"];
# q1 -> q3 [label="x"];
# q1 -> sink [label="t"];
# q1 -> sink [label="p"];
# q1 -> sink [label="v"];
# q2 -> q2 [label="t"];
# q2 -> q4 [label="v"];
# q2 -> sink [label="s"];
# q2 -> sink [label="x"];
# q2 -> sink [label="p"];
# q3 -> q5 [label="s"];
# q3 -> q2 [label="x"];
# q3 -> sink [label="t"];
# q3 -> sink [label="p"];
# q3 -> sink [label="v"];
# q4 -> q3 [label="p"];
# q4 -> q5 [label="v"];
# q4 -> sink [label="s"];
# q4 -> sink [label="x"];
# q4 -> sink [label="t"];
# q5 -> sink [label="t"];
# q5 -> sink [label="p"];
# q5 -> sink [label="s"];
# q5 -> sink [label="x"];
# q5 -> sink [label="v"];
# sink -> sink [label="t"];
# sink -> sink [label="p"];
# sink -> sink [label="s"];
# sink -> sink [label="x"];
# sink -> sink [label="v"];
# __start0 [shape=none, label=""];
# __start0 -> q0 [label=""];
# }
#
# digraph learnedModel {
# s0 [label="s0"];
# s1 [label="s1"];
# s2 [label="s2"];
# s3 [label="s3"];
# s4 [label="s4"];
# s5 [label="s5"];
# s6 [label="s6", shape=doublecircle];
# s0 -> s3 [label="t"];
# s0 -> s1 [label="p"];
# s0 -> s2 [label="s"];
# s0 -> s2 [label="x"];
# s0 -> s2 [label="v"];
# s1 -> s1 [label="t"];
# s1 -> s2 [label="p"];
# s1 -> s2 [label="s"];
# s1 -> s2 [label="x"];
# s1 -> s4 [label="v"];
# s2 -> s2 [label="t"];
# s2 -> s2 [label="p"];
# s2 -> s2 [label="s"];
# s2 -> s2 [label="x"];
# s2 -> s2 [label="v"];
# s3 -> s2 [label="t"];
# s3 -> s2 [label="p"];
# s3 -> s3 [label="s"];
# s3 -> s5 [label="x"];
# s3 -> s2 [label="v"];
# s4 -> s2 [label="t"];
# s4 -> s5 [label="p"];
# s4 -> s2 [label="s"];
# s4 -> s2 [label="x"];
# s4 -> s6 [label="v"];
# s5 -> s2 [label="t"];
# s5 -> s2 [label="p"];
# s5 -> s6 [label="s"];
# s5 -> s1 [label="x"];
# s5 -> s2 [label="v"];
# s6 -> s2 [label="t"];
# s6 -> s2 [label="p"];
# s6 -> s2 [label="s"];
# s6 -> s2 [label="x"];
# s6 -> s2 [label="v"];
# __start0 [shape=none, label=""];
# __start0 -> s0 [label=""];
# }

# %%
# Using RandomWMethodEqOracle
reber_dfa= get_reber_dfa()
alphabet = reber_dfa.get_input_alphabet()

sul = AutomatonSUL(reber_dfa)
eq_oracle = RandomWMethodEqOracle(alphabet, sul, 1500)

learned_dfa = run_Lstar(alphabet, sul, eq_oracle, automaton_type='dfa',
                        cache_and_non_det_check=True, cex_processing=None, print_level=3)

assert learned_dfa == reber_dfa

print(reber_dfa)

print(learned_dfa)
# Out:
# Hypothesis 1: 1 states.
# ------------------------
# Prefixes / E set |()
# ------------------------
# ()               |False
# ========================
# ------------------------
# ('t',)           |False
# ------------------------
# ('p',)           |False
# ------------------------
# ('s',)           |False
# ------------------------
# ('x',)           |False
# ------------------------
# ('v',)           |False
# ------------------------
# Counterexample ('t', 'x', 's')
# Hypothesis 2: 4 states.
# ----------------------------------------------------
# Prefixes / E set     |()    |('s',) |('x', 's')
# ----------------------------------------------------
# ()                   |False |False  |(False, False)
# ----------------------------------------------------
# ('t',)               |False |False  |(False, True)
# ----------------------------------------------------
# ('t', 'x')           |False |True   |(False, False)
# ----------------------------------------------------
# ('t', 'x', 's')      |True  |False  |(False, False)
# ====================================================
# ----------------------------------------------------
# ('p',)               |False |False  |(False, False)
# ----------------------------------------------------
# ('s',)               |False |False  |(False, False)
# ----------------------------------------------------
# ('x',)               |False |False  |(False, False)
# ----------------------------------------------------
# ('v',)               |False |False  |(False, False)
# ----------------------------------------------------
# ('t', 't')           |False |False  |(False, False)
# ----------------------------------------------------
# ('t', 'p')           |False |False  |(False, False)
# ----------------------------------------------------
# ('t', 's')           |False |False  |(False, True)
# ----------------------------------------------------
# ('t', 'v')           |False |False  |(False, False)
# ----------------------------------------------------
# ('t', 'x', 't')      |False |False  |(False, False)
# ----------------------------------------------------
# ('t', 'x', 'p')      |False |False  |(False, False)
# ----------------------------------------------------
# ('t', 'x', 'x')      |False |False  |(False, False)
# ----------------------------------------------------
# ('t', 'x', 'v')      |False |False  |(False, False)
# ----------------------------------------------------
# ('t', 'x', 's', 't') |False |False  |(False, False)
# ----------------------------------------------------
# ('t', 'x', 's', 'p') |False |False  |(False, False)
# ----------------------------------------------------
# ('t', 'x', 's', 's') |False |False  |(False, False)
# ----------------------------------------------------
# ('t', 'x', 's', 'x') |False |False  |(False, False)
# ----------------------------------------------------
# ('t', 'x', 's', 'v') |False |False  |(False, False)
# ----------------------------------------------------
# Counterexample ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's')
# Hypothesis 3: 5 states.
# -----------------------------------------------------------------------------------------------------------------------------
# Prefixes / E set                                                       |()    |('s',) |('x', 's')     |('t', 'x', 's')
# -----------------------------------------------------------------------------------------------------------------------------
# ()                                                                     |False |False  |(False, False) |(False, False, True)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t',)                                                                 |False |False  |(False, True)  |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x')                                                             |False |True   |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 's')                                                        |True  |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't')                                                        |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't')                                                   |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's')                                              |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p')                                         |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x')                                    |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's')                               |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p')                          |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't')                     |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's')                |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x')           |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's')      |False |False  |(False, False) |(False, False, False)
# =============================================================================================================================
# -----------------------------------------------------------------------------------------------------------------------------
# ('p',)                                                                 |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('s',)                                                                 |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('x',)                                                                 |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('v',)                                                                 |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 't')                                                             |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'p')                                                             |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 's')                                                             |False |False  |(False, True)  |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'v')                                                             |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 'p')                                                        |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 'x')                                                        |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 'v')                                                        |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 't')                                                   |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 'p')                                                   |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 's')                                                   |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 'x')                                                   |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 'v')                                                   |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 'p')                                                   |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 's')                                                   |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 'x')                                                   |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 'v')                                                   |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 't')                                              |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 'p')                                              |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 'x')                                              |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 'v')                                              |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 't')                                         |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 's')                                         |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'x')                                         |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'v')                                         |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 't')                                    |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'p')                                    |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 's')                                    |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'v')                                    |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 't')                               |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 'p')                               |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 'x')                               |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 'v')                               |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 't')                          |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 's')                          |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'x')                          |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'v')                          |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 'p')                     |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 's')                     |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 'x')                     |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 'v')                     |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 't')                |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 'p')                |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 'x')                |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 'v')                |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 't')           |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'p')           |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 's')           |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'v')           |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 't')      |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 'p')      |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 'x')      |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 'v')      |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's', 't') |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's', 'p') |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's', 's') |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's', 'x') |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's', 'v') |False |False  |(False, False) |(False, False, False)
# -----------------------------------------------------------------------------------------------------------------------------
# Counterexample ('p', 'v', 'p', 's')
# Hypothesis 4: 7 states.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Prefixes / E set                                                       |()    |('s',) |('x', 's')     |('t', 'x', 's')       |('p', 's')     |('v', 'p', 's')
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ()                                                                     |False |False  |(False, False) |(False, False, True)  |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t',)                                                                 |False |False  |(False, True)  |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p',)                                                                 |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, True)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x')                                                             |False |True   |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v')                                                             |False |False  |(False, False) |(False, False, False) |(False, True)  |(True, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 's')                                                        |True  |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't')                                                        |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'p')                                                        |False |True   |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'p', 's')                                                   |True  |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's')                                              |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p')                                         |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x')                                    |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's')                               |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p')                          |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't')                     |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's')                |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x')           |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's')      |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# ====================================================================================================================================================================
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('s',)                                                                 |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('x',)                                                                 |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('v',)                                                                 |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 't')                                                             |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'p')                                                             |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 's')                                                             |False |False  |(False, True)  |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'v')                                                             |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 't')                                                             |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, True)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'p')                                                             |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 's')                                                             |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'x')                                                             |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 'p')                                                        |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 'x')                                                        |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, True)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 'v')                                                        |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 't')                                                        |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 's')                                                        |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'x')                                                        |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'v')                                                        |True  |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 't')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 'p')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 's')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 'x')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 's', 'v')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 'p')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 's')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 'x')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 'v')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'p', 't')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'p', 'p')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'p', 'x')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, True)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'p', 'v')                                                   |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 't')                                              |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 'p')                                              |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 'x')                                              |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 'v')                                              |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'p', 's', 't')                                              |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'p', 's', 'p')                                              |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'p', 's', 's')                                              |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'p', 's', 'x')                                              |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('p', 'v', 'p', 's', 'v')                                              |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 't')                                         |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 's')                                         |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'x')                                         |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'v')                                         |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 't')                                    |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'p')                                    |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 's')                                    |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'v')                                    |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 't')                               |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 'p')                               |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 'x')                               |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 'v')                               |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 't')                          |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 's')                          |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'x')                          |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'v')                          |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 'p')                     |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 's')                     |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 'x')                     |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 'v')                     |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 't')                |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 'p')                |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 'x')                |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 'v')                |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 't')           |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'p')           |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 's')           |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'v')           |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 't')      |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 'p')      |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 'x')      |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 'v')      |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's', 't') |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's', 'p') |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's', 's') |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's', 'x') |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ('t', 'x', 't', 't', 's', 'p', 'x', 's', 'p', 't', 's', 'x', 's', 'v') |False |False  |(False, False) |(False, False, False) |(False, False) |(False, False, False)
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# -----------------------------------
# Learning Finished.
# Learning Rounds:  4
# Number of states: 7
# Time (in seconds)
#   Total                : 0.48
#   Learning algorithm   : 0.02
#   Conformance checking : 0.46
# Learning Algorithm
#  # Membership Queries  : 440
#  # MQ Saved by Caching : 139
#  # Steps               : 3830
# Equivalence Query
#  # Membership Queries  : 10500
#  # Steps               : 105522
# -----------------------------------
# digraph learnedModel {
# q0 [label="q0"];
# q1 [label="q1"];
# q2 [label="q2"];
# q3 [label="q3"];
# q4 [label="q4"];
# q5 [label="q5", shape=doublecircle];
# sink [label="sink"];
# q0 -> q1 [label="t"];
# q0 -> q2 [label="p"];
# q0 -> sink [label="s"];
# q0 -> sink [label="x"];
# q0 -> sink [label="v"];
# q1 -> q1 [label="s"];
# q1 -> q3 [label="x"];
# q1 -> sink [label="t"];
# q1 -> sink [label="p"];
# q1 -> sink [label="v"];
# q2 -> q2 [label="t"];
# q2 -> q4 [label="v"];
# q2 -> sink [label="s"];
# q2 -> sink [label="x"];
# q2 -> sink [label="p"];
# q3 -> q5 [label="s"];
# q3 -> q2 [label="x"];
# q3 -> sink [label="t"];
# q3 -> sink [label="p"];
# q3 -> sink [label="v"];
# q4 -> q3 [label="p"];
# q4 -> q5 [label="v"];
# q4 -> sink [label="s"];
# q4 -> sink [label="x"];
# q4 -> sink [label="t"];
# q5 -> sink [label="t"];
# q5 -> sink [label="p"];
# q5 -> sink [label="s"];
# q5 -> sink [label="x"];
# q5 -> sink [label="v"];
# sink -> sink [label="t"];
# sink -> sink [label="p"];
# sink -> sink [label="s"];
# sink -> sink [label="x"];
# sink -> sink [label="v"];
# __start0 [shape=none, label=""];
# __start0 -> q0 [label=""];
# }
#
# digraph learnedModel {
# s0 [label="s0"];
# s1 [label="s1"];
# s2 [label="s2"];
# s3 [label="s3"];
# s4 [label="s4"];
# s5 [label="s5", shape=doublecircle];
# s6 [label="s6"];
# s0 -> s1 [label="t"];
# s0 -> s2 [label="p"];
# s0 -> s6 [label="s"];
# s0 -> s6 [label="x"];
# s0 -> s6 [label="v"];
# s1 -> s6 [label="t"];
# s1 -> s6 [label="p"];
# s1 -> s1 [label="s"];
# s1 -> s3 [label="x"];
# s1 -> s6 [label="v"];
# s2 -> s2 [label="t"];
# s2 -> s6 [label="p"];
# s2 -> s6 [label="s"];
# s2 -> s6 [label="x"];
# s2 -> s4 [label="v"];
# s3 -> s6 [label="t"];
# s3 -> s6 [label="p"];
# s3 -> s5 [label="s"];
# s3 -> s2 [label="x"];
# s3 -> s6 [label="v"];
# s4 -> s6 [label="t"];
# s4 -> s3 [label="p"];
# s4 -> s6 [label="s"];
# s4 -> s6 [label="x"];
# s4 -> s5 [label="v"];
# s5 -> s6 [label="t"];
# s5 -> s6 [label="p"];
# s5 -> s6 [label="s"];
# s5 -> s6 [label="x"];
# s5 -> s6 [label="v"];
# s6 -> s6 [label="t"];
# s6 -> s6 [label="p"];
# s6 -> s6 [label="s"];
# s6 -> s6 [label="x"];
# s6 -> s6 [label="v"];
# __start0 [shape=none, label=""];
# __start0 -> s0 [label=""];
# }

# %% [markdown]
# ## RNN learning of the Reber dfa following the methodology of Cleeremans et al.

# %%
# Cleeremans et al. seem to be using a one-hot encoding of the five letters p,s,t,v,x. 
# Will use [0,0,0,0,0] for none of them
dim_in = 5; dim_out = 5

# Set up training data because of the sink state we've added we can use any random element of {p,s,t,v,x}*
x_train = 


model=Sequential()
# They mention 3 hidden units (sec 2, p3)
model.add(SimpleRNN(input_shape=(None, dim_in), 
                    return_sequences=True, 
                    units=3))
model.add(TimeDistributed(Dense(activation='sigmoid',
                                units=dim_out)))

# %%
# Function returning random strings
from scipy.stats import poisson
import numpy as np

def get_random_strings(rate, size, chars):
    random_strings = []
    # sample the lengths of the random strings
    lengths = poisson.rvs(mu = rate, size=size)
    # get the right amount of characters
    symbols = np.random.choice(chars, np.sum(lengths))
    k = 0
    for l in lengths:
        random_strings.append(''.join(symbols[k:k+l-1]))
        k+=l
    return random_strings

# Function testing membership
def query(automaton, word):
    # Empty string for DFA
    if len(word) == 0:
        out = [automaton.step(None)]
    else:
        out = [automaton.step(letter) for letter in word]
    return out

# %%
reber_dfa= get_reber_dfa()
output = query(reber_dfa, 'txst')
print(output)
# Out:
# [False, False, True, False]
